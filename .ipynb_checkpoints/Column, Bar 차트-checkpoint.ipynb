# %%
# Import pandas as a alias 'pd'
import pandas as pd

# Load the CSV files "marathon_results_2015 ~ 2017.csv" under "data" folder
marathon_2015_2017 = pd.read_csv("./data/marathon_2015_2017.csv")

# Import pyplot as a alias 'plt'
import matplotlib.pyplot as plt
# Import seaborn as a alias 'sns'
import seaborn as sns

# %%
marathon_2015_2017.head()
# Out:
#                     Name  Age M/F         City State Country   5K   10K   15K  \
# 0         Desisa, Lelisa   25   M         Ambo   NaN     ETH  883  1783  2697
# 1  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH  883  1783  2698
# 2         Chebet, Wilson   29   M     Marakwet   NaN     KEN  883  1783  2697
# 3       Kipyego, Bernard   28   M      Eldoret   NaN     KEN  883  1784  2701
# 4          Korir, Wesley   32   M       Kitale   NaN     KEN  883  1784  2698
#
#     20K  ...   25K   30K   35K   40K  Pace  Official Time  Overall  Gender  \
# 0  3629  ...  4567  5520  6479  7359   296           7757        1       1
# 1  3628  ...  4567  5519  6479  7362   298           7788        2       2
# 2  3629  ...  4567  5520  6479  7381   299           7822        3       3
# 3  3629  ...  4567  5520  6483  7427   300           7847        4       4
# 4  3628  ...  4567  5520  6479  7407   300           7849        5       5
#
#    Division  Year
# 0         1  2015
# 1         2  2015
# 2         3  2015
# 3         4  2015
# 4         5  2015
#
# [5 rows x 21 columns]

# %%
# Select runners from USA by conditional expression
USA_runner = marathon_2015_2017[marathon_2015_2017.Country == 'USA']

# %%
USA_runner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64474 entries, 6 to 79637
# Data columns (total 21 columns):
# Name             64474 non-null object
# Age              64474 non-null int64
# M/F              64474 non-null object
# City             64474 non-null object
# State            64474 non-null object
# Country          64474 non-null object
# 5K               64474 non-null int64
# 10K              64474 non-null int64
# 15K              64474 non-null int64
# 20K              64474 non-null int64
# Half             64474 non-null int64
# 25K              64474 non-null int64
# 30K              64474 non-null int64
# 35K              64474 non-null int64
# 40K              64474 non-null int64
# Pace             64474 non-null int64
# Official Time    64474 non-null int64
# Overall          64474 non-null int64
# Gender           64474 non-null int64
# Division         64474 non-null int64
# Year             64474 non-null int64
# dtypes: int64(16), object(5)
# memory usage: 10.8+ MB

# %%
# Configure figure size
plt.figure(figsize=(20,10))
# Number of Runner by State - USA
runner_state = sns.countplot('State',data=USA_runner)
runner_state.set_title('Number of Runner by State - USA', fontsize=18)
runner_state.set_xlabel('State', fontdict= {'size':16})
runner_state.set_ylabel('Number of Runner', fontdict= {'size':16})
plt.show()

# %%
plt.figure(figsize=(20,10))
# Number of Runner by State, Gender - USA
runner_state = sns.countplot('State',data=USA_runner, hue='M/F',  palette={'F':'r','M':'b'})
runner_state.set_title('Number of Runner by State, Gender - USA', fontsize=18)
runner_state.set_xlabel('State', fontdict= {'size':16})
runner_state.set_ylabel('Number of Runner', fontdict= {'size':16})
plt.show()

# %%
plt.figure(figsize=(20,10))
# Number of Runner by State, year - USA
runner_state = sns.countplot('State',data=USA_runner, hue='Year')
runner_state.set_title('Number of Runner by State, year - USA', fontsize=18)
runner_state.set_xlabel('State', fontdict= {'size':16})
runner_state.set_ylabel('Number of Runner', fontdict= {'size':16})
plt.show()
